# %%
import numpy as np
import scipy.stats
import pandas as pd
import seaborn as sns
import os.path
import matplotlib.pyplot as plt
import statsmodels.sandbox.stats.multicomp

# %%
# %matplotlib inline
sns.set_style("white")
from IPython.core.pylabtools import figsize

# %% [markdown]
# # Load linkage map

# %%
linkage_map = pd.read_csv(os.path.join('linkage_map', 'LEPmap', 'with_paralogs', 'final', 'PS_chum_map_2015.txt'), sep = '\t')
linkage_map = linkage_map[['contig', 'resolved_locus', 'stacks_CatID', 'stacks_SNP', 'LEP_LG', 'cM']]
linkage_map = linkage_map.rename(columns = {'resolved_locus':'locus', 'LEP_LG':'LG'})
linkage_map.head(3)
# Out:
#    contig  locus  stacks_CatID stacks_SNP  LG  cM
# 0   c4311   4311         28282   28282_88   1   0
# 1   c4311   4311         28282   28282_91   1   0
# 2  c56875  56875         39970   39970_17   1   0

# %%
 ### Get the Bayescan ID for each locus

# %%
# in the output from plink, column 2 is what we want
stacks_SNPs = pd.read_csv(os.path.join('results', 'batch_4', 'pop_analysis', 'bayescan', 'non_paralogs.map'),                        
            header = None, sep = '\t')
stacks_SNPs.columns =  ['ignore1', 'stacks_SNP', 'ignore2', 'ignore3']
stacks_SNPs['BSname'] = stacks_SNPs.index + 1
stacks_SNPs = stacks_SNPs[['stacks_SNP', 'BSname']]
stacks_SNPs.head(3)
# Out:
#   stacks_SNP  BSname
# 0     1013_6       1
# 1     2062_6       2
# 2     2574_6       3

# %%
lmap_BSnames = pd.merge(linkage_map, stacks_SNPs, how='outer')
lmap_BSnames.head()
# Out:
#    contig  locus  stacks_CatID stacks_SNP  LG  cM  BSname
# 0   c4311   4311         28282   28282_88   1   0    6440
# 1   c4311   4311         28282   28282_91   1   0     NaN
# 2  c56875  56875         39970   39970_17   1   0     NaN
# 3  c56875  56875         39970   39970_33   1   0     NaN
# 4  c56875  56875         39970   39970_49   1   0     NaN

# %%
len(lmap_BSnames)
# Out:
# 19063

# %% [markdown]
# ## Load Bayescan results

# %%
group_2_fst_file = os.path.join('results', 'batch_4', 'pop_analysis', 'bayescan', 'BS_group_2.baye_fst.txt')


def load_baye_fst(filename):
    baye_fst = pd.read_csv(filename, sep = " ", skiprows=1, header = None, skipinitialspace=True)
    baye_fst.columns = ['BSname','prob_bayescan','log10(PO)_bayescan','qval_bayescan','alpha_bayescan','Fst_bayescan', 'junk']
    baye_fst = baye_fst[['BSname','prob_bayescan','log10(PO)_bayescan','qval_bayescan','alpha_bayescan','Fst_bayescan']]
    baye_fst['mlog10(qval)_bayescan'] = -np.log10(baye_fst['qval_bayescan'])

    return(baye_fst)

BS_2 = load_baye_fst(group_2_fst_file)
BS_2.head()
# Out:
#    BSname  prob_bayescan  log10(PO)_bayescan  qval_bayescan  alpha_bayescan  \
# 0       1       0.079708            -1.06242       0.858659       -0.034193
# 1       2       0.106910            -0.92187       0.725970       -0.077808
# 2       3       0.070507            -1.12000       0.883910       -0.022087
# 3       4       0.117810            -0.87437       0.643790       -0.099951
# 4       5       0.082108            -1.04840       0.850000       -0.036494
#
#    Fst_bayescan  mlog10(qval)_bayescan
# 0      0.027787               0.066179
# 1      0.027054               0.139081
# 2      0.027977               0.053592
# 3      0.026676               0.191256
# 4      0.027769               0.070581

# %%
lmap_BS = pd.merge(lmap_BSnames, BS_2, how = 'outer')
lmap_BS.head()
# Out:
#    contig  locus  stacks_CatID stacks_SNP  LG  cM  BSname  prob_bayescan  \
# 0   c4311   4311         28282   28282_88   1   0    6440       0.074607
# 1   c4311   4311         28282   28282_91   1   0     NaN            NaN
# 2  c56875  56875         39970   39970_17   1   0     NaN            NaN
# 3  c56875  56875         39970   39970_33   1   0     NaN            NaN
# 4  c56875  56875         39970   39970_49   1   0     NaN            NaN
#
#    log10(PO)_bayescan  qval_bayescan  alpha_bayescan  Fst_bayescan  \
# 0             -1.0935        0.87532        -0.00809      0.028428
# 1                 NaN            NaN             NaN           NaN
# 2                 NaN            NaN             NaN           NaN
# 3                 NaN            NaN             NaN           NaN
# 4                 NaN            NaN             NaN           NaN
#
#    mlog10(qval)_bayescan
# 0               0.057833
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %% [markdown]
# ## Combine with Weir (1984) Fst

# %%
plink_fst = pd.read_csv(os.path.join('data', 'batch_4', 'pop_genotypes', 'non_paralogs.fst'), sep = "\t")
plink_fst= plink_fst.rename(columns = {'SNP':'stacks_SNP', 'FST':'Fst_weir'})
plink_fst = plink_fst[['stacks_SNP','Fst_weir']]
plink_fst.head()
# Out:
#   stacks_SNP  Fst_weir
# 0     1013_6  0.015589
# 1     2062_6 -0.002161
# 2     2574_6  0.017541
# 3     2741_6 -0.005708
# 4     4096_6  0.010227

# %%
lmap_BS_FST = pd.merge(lmap_BS,plink_fst, how = 'outer')

# %% [markdown]
# ## Combine with LFMM statistics

# %% [markdown]
# here just for non-duplicated loci

# %%
lfmm = pd.read_csv('/home/ipseg/Desktop/waples/chum_populations/results/batch_4/LFMM/lfmm_results.txt', sep = '\t')
lfmm.head()
# Out:
#    locnum    cpvals    zscore
# 0       1  0.429470 -0.846787
# 1       2  0.780930  0.298061
# 2       3  0.675836 -0.448154
# 3       4  0.324520  1.055900
# 4       5  0.716019 -0.389885

# %% [markdown]
# Apply FDR correction

# %%
reject_null, fdr_pval, alphacSidak, alphacBonf = statsmodels.sandbox.stats.multicomp.multipletests(lfmm['cpvals'], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)
lfmm['reject_null_LFMM'] = reject_null
lfmm['fdr_pval_LFMM'] = fdr_pval
lfmm.head()
# Out:
#    locnum    cpvals    zscore reject_null reject_null_LFMM  fdr_pval_LFMM
# 0       1  0.429470 -0.846787       False            False       0.990170
# 1       2  0.780930  0.298061       False            False       0.997092
# 2       3  0.675836 -0.448154       False            False       0.997092
# 3       4  0.324520  1.055900       False            False       0.975990
# 4       5  0.716019 -0.389885       False            False       0.997092

# %%
lmap_BS_FST_LFMM = pd.merge(lmap_BS_FST, lfmm, how = 'outer', left_on='BSname', right_on='locnum')
lmap_BS_FST_LFMM.head()
# Out:
#    contig  locus  stacks_CatID stacks_SNP  LG  cM  BSname  prob_bayescan  \
# 0   c4311   4311         28282   28282_88   1   0    6440       0.074607
# 1   c4311   4311         28282   28282_91   1   0     NaN            NaN
# 2  c56875  56875         39970   39970_17   1   0     NaN            NaN
# 3  c56875  56875         39970   39970_33   1   0     NaN            NaN
# 4  c56875  56875         39970   39970_49   1   0     NaN            NaN
#
#    log10(PO)_bayescan  qval_bayescan  alpha_bayescan  Fst_bayescan  \
# 0             -1.0935        0.87532        -0.00809      0.028428
# 1                 NaN            NaN             NaN           NaN
# 2                 NaN            NaN             NaN           NaN
# 3                 NaN            NaN             NaN           NaN
# 4                 NaN            NaN             NaN           NaN
#
#    mlog10(qval)_bayescan  Fst_weir  locnum    cpvals    zscore reject_null  \
# 0               0.057833  0.013742    6440  0.567927 -0.612083       False
# 1                    NaN       NaN     NaN       NaN       NaN         NaN
# 2                    NaN       NaN     NaN       NaN       NaN         NaN
# 3                    NaN       NaN     NaN       NaN       NaN         NaN
# 4                    NaN       NaN     NaN       NaN       NaN         NaN
#
#   reject_null_LFMM  fdr_pval_LFMM
# 0            False       0.995929
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN

# %% [markdown]
# # Select only loci on linkage map and scored for population genetic stats

# %%
lmap_BS_FST_LFMM = lmap_BS_FST_LFMM[lmap_BS_FST_LFMM['LG'].notnull()]
lmap_BS_FST_LFMM = lmap_BS_FST_LFMM[lmap_BS_FST_LFMM['BSname'].notnull()]
lmap_BS_FST_LFMM
# Out:
#        contig  locus  stacks_CatID stacks_SNP  LG     cM  BSname  \
# 0       c4311   4311         28282   28282_88   1   0.00    6440
# 6665   c56875  56875         39970   39970_60   1   0.00    6348
# 6666   c54045  54045         37579   37579_17   1   0.00    6197
# 6667    c2167   2167         10293    10293_9   1   0.00    6162
# 6668   c69918  69918         50820    50820_7   1   0.00    6154
# 6669   c23377  23377         11724   11724_38   1   0.00    6270
# 6670   c18893  18893          7852    7852_77   1   0.00    6404
# 6671    c7037   7037         51187   51187_79   1   0.00    6411
# 6672   c38827  38827         24722   24722_39   1   0.00    6276
# 6673   c55880  55880         39141   39141_28   1   0.00    6241
# 6674    c7032   7032         51148   51148_30   1   0.00    6248
# 6675    c9532   9532         67786   67786_55   1   0.00    6331
# 6676   c83187  83187         61847   61847_12   1   0.00    6174
# 6677   c60227  60227         42827    42827_9   1   0.00    6163
# 6678    c9669   9669         68084   68084_56   1   0.00    6336
# 6679   c60695  60695         43220   43220_70   1   0.00    6375
# 6680    c7842   7842         57722   57722_26   1   0.00    6235
# 6681   c28714  28714         16231   16231_83   1   0.00    6419
# 6682   c22237  22237         10766   10766_25   1   0.00    6225
# 6683   c47463  47463         32003   32003_55   1   0.00    6329
# 6684   c46019  46019         30764    30764_8   1   0.00    6156
# 6685   c88177  88177         66157   66157_68   1   0.00    6370
# 6686    c8781   8781         65853   65853_72   1   0.00    6386
# 6687   c73675  73675         53865   53865_80   1   0.00    6412
# 6688   c27947  27947         15571   15571_41   1   0.00    6287
# 6689   c12584  12584          2287    2287_40   1   0.00    6281
# 6690   c57789  57789         40757   40757_10   1   0.00    6167
# 6691   c60553  60553         43108   43108_26   1   0.00    6233
# 6692    c8789   8789         65921   65921_82   1   0.00    6418
# 6693   c50898  50898         34919   34919_74   1   0.00    6394
# ...       ...    ...           ...        ...  ..    ...     ...
# 12885  c46856  46856         31479   31479_51  32  22.70    9696
# 12886   c4714   4714         31735   31735_24  32  20.55    9657
# 12887  c63644  63644         45699   45699_10  32  20.55    9632
# 12888  c16600  16600          5834    5834_16  32  20.55    9643
# 12889  c27196  27196         14919   14919_70  32  20.55    9723
# 12890  c74400  74400         54450   54450_13  32  20.55    9637
# 12891  c27500  27500         15186   15186_52  32  20.55    9699
# 12892  c73756  73756         53927    53927_8  32  20.55    9630
# 12893  c53702  53702         37289   37289_84  32  20.55    9756
# 12894  c66187  66187         47795   47795_74  32  20.55    9738
# 12895  c13227  13227          2856    2856_77  32  20.55    9743
# 12896   c5779   5779         40764   40764_28  32  20.55    9664
# 12897   c3360   3360         20369   20369_53  32  20.55    9702
# 12898  c73777  73777         53945   53945_21  32  18.86    9652
# 12899  c72073  72073         52561   52561_55  32  18.86    9707
# 12900  c55429  55429         38747   38747_88  32  18.86    9762
# 12901  c70614  70614         51379   51379_40  32  15.81    9683
# 12902  c53557  53557         37156   37156_68  32  15.81    9718
# 12903  c10323  10323           288     288_40  32  12.22    9681
# 12904  c47493  47493         32026   32026_90  32   8.19    9767
# 12905  c64554  64554         46461   46461_73  32   8.19    9735
# 12906  c54268  54268         37762   37762_74  32   5.20    9737
# 12907  c64202  64202         46171   46171_71  32   5.20    9728
# 12908  c23271  23271         11638   11638_43  32   4.47    9688
# 12909  c62315  62315         44589   44589_22  32   4.47    9653
# 12910     c78     78         58168   58168_32  32   0.69    9669
# 12911  c24809  24809         12931   12931_23  32   0.67    9655
# 12912  c15843  15843          5166    5166_16  32   0.65    9642
# 12913  c14448  14448          3936    3936_64  32   0.63    9714
# 12914  c19932  19932          8761    8761_84  32   0.00    9755
#
#        prob_bayescan  log10(PO)_bayescan  qval_bayescan  alpha_bayescan  \
# 0           0.074607            -1.09350        0.87532       -0.008090
# 6665        0.070007            -1.12330        0.88464       -0.019498
# 6666        0.069907            -1.12400        0.88481        0.004748
# 6667        0.075208            -1.08980        0.87376       -0.016256
# 6668        0.069207            -1.12870        0.88562       -0.019918
# 6669        0.158620            -0.72465        0.44106        0.145070
# 6670        0.079208            -1.06540        0.86047       -0.040250
# 6671        0.289730            -0.38943        0.27968        0.343150
# 6672        0.065707            -1.15290        0.88861        0.010490
# 6673        1.000000          1000.00000        0.00000        1.734400
# 6674        0.101010            -0.94939        0.76305        0.053886
# 6675        0.094409            -0.98192        0.79848       -0.050874
# 6676        0.086409            -1.02420        0.83358        0.045718
# 6677        0.310630            -0.34621        0.26804        0.362270
# 6678        0.081208            -1.05360        0.85338       -0.035536
# 6679        0.077408            -1.07620        0.86723        0.002154
# 6680        0.073607            -1.09990        0.87787        0.023462
# 6681        0.493450            -0.01138        0.15159        0.654540
# 6682        0.074907            -1.09170        0.87459       -0.020049
# 6683        0.071707            -1.11210        0.88200       -0.007066
# 6684        0.068807            -1.13140        0.88608       -0.017006
# 6685        0.077208            -1.07740        0.86781        0.020303
# 6686        0.070507            -1.12000        0.88391        0.009073
# 6687        0.626760             0.22512        0.10174        0.762270
# 6688        0.069507            -1.12670        0.88534       -0.005391
# 6689        0.073407            -1.10110        0.87832        0.017806
# 6690        0.075408            -1.08850        0.87333       -0.028159
# 6691        0.073807            -1.09860        0.87735        0.020570
# 6692        0.083008            -1.04320        0.84640        0.023961
# 6693        0.073607            -1.09990        0.87787       -0.016686
# ...              ...                 ...            ...             ...
# 12885       0.074907            -1.09170        0.87459       -0.017098
# 12886       0.074907            -1.09170        0.87459       -0.005985
# 12887       0.087809            -1.01650        0.82785       -0.052936
# 12888       0.069107            -1.12940        0.88573        0.014000
# 12889       0.108410            -0.91509        0.71460       -0.085392
# 12890       0.071807            -1.11150        0.88181       -0.008171
# 12891       0.098510            -0.96148        0.77788       -0.070205
# 12892       0.067107            -1.14310        0.88761       -0.004936
# 12893       0.104810            -0.93151        0.74074       -0.072759
# 12894       0.077408            -1.07620        0.86723        0.012963
# 12895       0.065207            -1.15640        0.88890        0.019059
# 12896       0.071207            -1.11540        0.88285       -0.018412
# 12897       0.073907            -1.09800        0.87709       -0.016480
# 12898       0.064806            -1.15930        0.88909       -0.014126
# 12899       0.086909            -1.02150        0.83141        0.036257
# 12900       0.071507            -1.11340        0.88236       -0.020186
# 12901       0.064406            -1.16220        0.88928       -0.005600
# 12902       0.088809            -1.01120        0.82350       -0.048675
# 12903       0.069507            -1.12670        0.88534       -0.003631
# 12904       0.074207            -1.09610        0.87623       -0.007853
# 12905       0.089209            -1.00900        0.82166       -0.048045
# 12906       0.070007            -1.12330        0.88464       -0.004406
# 12907       0.072507            -1.10690        0.88026       -0.018411
# 12908       0.084908            -1.03250        0.83949       -0.024300
# 12909       0.080208            -1.05950        0.85661       -0.035838
# 12910       0.072007            -1.11020        0.88140       -0.009409
# 12911       0.071107            -1.11610        0.88297       -0.025320
# 12912       0.076408            -1.08230        0.87051       -0.019638
# 12913       0.073807            -1.09860        0.87735        0.006227
# 12914       0.076508            -1.08170        0.87010       -0.031576
#
#        Fst_bayescan  mlog10(qval)_bayescan  Fst_weir  locnum    cpvals  \
# 0          0.028428               0.057833  0.013742    6440  0.567927
# 6665       0.027983               0.053233  0.016345    6348  0.245650
# 6666       0.028735               0.053150  0.028103    6197  0.761393
# 6667       0.028102               0.058608  0.014312    6162  0.502838
# 6668       0.027949               0.052753  0.015249    6154  0.371955
# 6669       0.035623               0.355502  0.070550    6270  0.007111
# 6670       0.027630               0.065264  0.002737    6404  0.732973
# 6671       0.046835               0.553339  0.073569    6411  0.448260
# 6672       0.028784               0.051289  0.035376    6276  0.521589
# 6673       0.141240                    inf  0.196219    6241  0.644250
# 6674       0.030999               0.117447  0.052052    6248  0.468304
# 6675       0.027497               0.097736 -0.004345    6331  0.931263
# 6676       0.030236               0.079053  0.095563    6174  0.727925
# 6677       0.047586               0.571800  0.085077    6163  0.559182
# 6678       0.027746               0.068858  0.001353    6336  0.053128
# 6679       0.028805               0.061866  0.036081    6375  0.239400
# 6680       0.029385               0.056570  0.044890    6235  0.064064
# 6681       0.064938               0.819329  0.105405    6419  0.004285
# 6682       0.028107               0.058195  0.016981    6225  0.218449
# 6683       0.028445               0.054531  0.021676    6329  0.670024
# 6684       0.028070               0.052527  0.030753    6156  0.956722
# 6685       0.029298               0.061575  0.045795    6370  0.185607
# 6686       0.028846               0.053592  0.016098    6386  0.812507
# 6687       0.068329               0.992508  0.090975    6412  0.717897
# 6688       0.028447               0.052890  0.033520    6287  0.728653
# 6689       0.029103               0.056347  0.052456    6281  0.066225
# 6690       0.027913               0.058822  0.009725    6167  0.897864
# 6691       0.029251               0.056827  0.062431    6233  0.692730
# 6692       0.029741               0.072424  0.039369    6418  0.853215
# 6693       0.028131               0.056570  0.002494    6394  0.645063
# ...             ...                    ...       ...     ...       ...
# 12885      0.028197               0.058195  0.022086    9696  0.897724
# 12886      0.028429               0.058195  0.027692    9657  0.835720
# 12887      0.027459               0.082048 -0.002429    9632  0.089478
# 12888      0.029019               0.052699  0.049907    9643  0.803434
# 12889      0.026898               0.145937 -0.018961    9723  0.824569
# 12890      0.028377               0.054625  0.032618    9637  0.465695
# 12891      0.027115               0.109087 -0.013487    9699  0.548463
# 12892      0.028440               0.051778  0.014491    9630  0.929290
# 12893      0.027097               0.130334 -0.005268    9756  0.964266
# 12894      0.029180               0.061866 -0.000408    9738  0.226715
# 12895      0.029038               0.051147  0.066185    9743  0.292825
# 12896      0.027990               0.054113  0.014065    9664  0.618066
# 12897      0.028152               0.056956  0.024298    9702  0.487226
# 12898      0.028082               0.051054  0.009798    9652  0.348787
# 12899      0.029998               0.080185  0.065277    9707  0.889321
# 12900      0.028074               0.054354  0.020598    9762  0.582799
# 12901      0.028372               0.050961  0.027205    9683  0.824743
# 12902      0.027574               0.084336 -0.000718    9718  0.409658
# 12903      0.028455               0.052890  0.026680    9681  0.850964
# 12904      0.028441               0.057382  0.022248    9767  0.763804
# 12905      0.027519               0.085308  0.000249    9735  0.855781
# 12906      0.028458               0.053233  0.039808    9737  0.156112
# 12907      0.028125               0.055389  0.008654    9728  0.561460
# 12908      0.028118               0.075984  0.026593    9688  0.224539
# 12909      0.027800               0.067217  0.005635    9653  0.064161
# 12910      0.028311               0.054827  0.062231    9669  0.029297
# 12911      0.027936               0.054054  0.003346    9655  0.943987
# 12912      0.028115               0.060226  0.014896    9642  0.409101
# 12913      0.028806               0.056827  0.037353    9714  0.447727
# 12914      0.027792               0.060431  0.021568    9755  0.580193
#
#          zscore reject_null reject_null_LFMM  fdr_pval_LFMM
# 0     -0.612083       False            False       0.995929
# 6665   1.244280       False            False       0.937707
# 6666  -0.325439       False            False       0.997092
# 6667   0.718105       False            False       0.995929
# 6668   0.956875       False            False       0.977007
# 6669  -2.884700       False            False       0.282609
# 6670   0.365652       False            False       0.997092
# 6671   0.812728       False            False       0.992568
# 6672  -0.686881       False            False       0.995929
# 6673   0.494896       False            False       0.995929
# 6674   0.777276       False            False       0.995929
# 6675   0.092444       False            False       0.997931
# 6676   0.372848       False            False       0.997092
# 6677  -0.625963       False            False       0.995929
# 6678  -2.072630       False            False       0.643776
# 6679  -1.260900       False            False       0.932797
# 6680  -1.984590       False            False       0.691930
# 6681  -3.061330       False            False       0.218636
# 6682   1.318960       False            False       0.913262
# 6683   0.456688       False            False       0.997092
# 6684   0.058161       False            False       0.997931
# 6685  -1.418660       False            False       0.896229
# 6686  -0.254212       False            False       0.997092
# 6687   0.387192       False            False       0.997092
# 6688  -0.371809       False            False       0.997092
# 6689   1.968690       False            False       0.698043
# 6690   0.137570       False            False       0.997931
# 6691  -0.423504       False            False       0.997092
# 6692  -0.198293       False            False       0.997812
# 6693   0.493681       False            False       0.995929
# ...         ...         ...              ...            ...
# 12885  0.137760       False            False       0.997931
# 12886  0.222250       False            False       0.997092
# 12887 -1.820000       False            False       0.760407
# 12888  0.266764       False            False       0.997092
# 12889  0.237577       False            False       0.997092
# 12890  0.781842       False            False       0.995929
# 12891  0.643118       False            False       0.995929
# 12892 -0.095106       False            False       0.997931
# 12893 -0.048015       False            False       0.997931
# 12894  1.295600       False            False       0.917096
# 12895 -1.127420       False            False       0.955695
# 12896 -0.534367       False            False       0.995929
# 12897 -0.744574       False            False       0.995929
# 12898 -1.004170       False            False       0.976586
# 12899 -0.149148       False            False       0.997931
# 12900 -0.588713       False            False       0.995929
# 12901  0.237338       False            False       0.997092
# 12902 -0.883652       False            False       0.988421
# 12903 -0.201370       False            False       0.997812
# 12904  0.322049       False            False       0.997092
# 12905  0.194787       False            False       0.997812
# 12906 -1.520030       False            False       0.861315
# 12907 -0.622337       False            False       0.995929
# 12908  1.301690       False            False       0.915881
# 12909  1.983870       False            False       0.692370
# 12910 -2.335840       False            False       0.505925
# 12911  0.075300       False            False       0.997931
# 12912  0.884703       False            False       0.988421
# 12913 -0.813682       False            False       0.992568
# 12914 -0.592788       False            False       0.995929
#
# [6251 rows x 20 columns]

# %% [markdown]
# ## Add 20cM between linkage groups - easier to visualize

# %%
cumpos = pd.DataFrame(lmap_BS_FST_LFMM.groupby('LG')['cM'].max().cumsum())
cumpos.index = cumpos.index+1
cumpos.set_value(1, 'cM', 0)
cumpos = cumpos.sort_index()
cumpos['cM_pad'] = cumpos['cM'] + np.arange(0,750, 20)
cumpos = cumpos[['cM_pad']]
cumpos.head()
# Out:
#     cM_pad
# LG
# 1     0.00
# 2   126.08
# 3   248.38
# 4   385.34
# 5   524.82

# %%
genome_stats = pd.merge(lmap_BS_FST_LFMM, cumpos, right_index=True, left_on = 'LG')
genome_stats['cM_padded'] = genome_stats['cM'] + genome_stats['cM_pad']

genome_stats.head()
# Out:
#       contig  locus  stacks_CatID stacks_SNP  LG  cM  BSname  prob_bayescan  \
# 0      c4311   4311         28282   28282_88   1   0    6440       0.074607
# 6665  c56875  56875         39970   39970_60   1   0    6348       0.070007
# 6666  c54045  54045         37579   37579_17   1   0    6197       0.069907
# 6667   c2167   2167         10293    10293_9   1   0    6162       0.075208
# 6668  c69918  69918         50820    50820_7   1   0    6154       0.069207
#
#       log10(PO)_bayescan  qval_bayescan    ...      mlog10(qval)_bayescan  \
# 0                -1.0935        0.87532    ...                   0.057833
# 6665             -1.1233        0.88464    ...                   0.053233
# 6666             -1.1240        0.88481    ...                   0.053150
# 6667             -1.0898        0.87376    ...                   0.058608
# 6668             -1.1287        0.88562    ...                   0.052753
#
#       Fst_weir  locnum    cpvals    zscore  reject_null  reject_null_LFMM  \
# 0     0.013742    6440  0.567927 -0.612083        False             False
# 6665  0.016345    6348  0.245650  1.244280        False             False
# 6666  0.028103    6197  0.761393 -0.325439        False             False
# 6667  0.014312    6162  0.502838  0.718105        False             False
# 6668  0.015249    6154  0.371955  0.956875        False             False
#
#      fdr_pval_LFMM cM_pad  cM_padded
# 0         0.995929      0          0
# 6665      0.937707      0          0
# 6666      0.997092      0          0
# 6667      0.995929      0          0
# 6668      0.977007      0          0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Rolling averages and bootstrapping

# %%
def roll_along(data, stat, positions, window_size = 5.0, minsize= 2):
    rolling_stat = []
    rolling_size = []
    for xx in positions:
        subset = data[data['cM_padded'] >= xx - window_size/2. ]
        subset = subset[subset['cM_padded'] <= xx + window_size/2.]
        subset = subset[subset[stat].notnull()]
        if len(subset) < minsize:
            val = np.NaN
        else:
            val = np.average(subset[stat], 
                             weights = get_weights(window_size = window_size, center = xx, positions = subset['cM_padded']))
        rolling_stat.append(val)
        rolling_size.append(len(subset))
    to_return = pd.DataFrame({stat+'_roll':rolling_stat, 'n':rolling_size, 'pos':positions})
    to_return = to_return[['pos', 'n', stat+'_roll']]
    return(to_return)

# %%
def get_weights(window_size, center, positions):
    # wei = .001+window_size-(np.abs(center - positions))
    # wei = 1./(1 + np.abs(center - positions))**power
    weights = 1./np.exp(np.abs(center - positions))
    return(weights)

# %%
def rolling_boostrap(data, stat, positions, window_size = 5.0, minsize= 2, reps = 1000):
    rolling_upper95 = []
    rolling_size = []
    for xx in positions:
        subset = data[data['cM_padded'] >= xx - window_size/2.]
        subset = subset[subset['cM_padded'] <= xx + window_size/2.]
        if len(subset) < minsize:
            val = np.NaN
        else:
            val = np.percentile([np.average(np.random.choice(data[stat].values, size = len(subset), replace = True), 
                                            weights = get_weights(window_size = window_size, center = xx, positions = subset['cM_padded'].values))
             for yy in range(reps)], 95)
            
        rolling_upper95.append(val)
        rolling_size.append(len(subset))
    to_return = pd.DataFrame({stat+'_bootstrap95':rolling_upper95, 'n':rolling_size, 'pos':positions})
    to_return = to_return[['pos', 'n', stat+'_bootstrap95']]
    return(to_return)

# %%
max_cM = max(genome_stats['cM_padded'])
cMs = np.arange(1, max_cM+1, 1.)
cMs
# Out:
# array([  1.00000000e+00,   2.00000000e+00,   3.00000000e+00, ...,
#          3.58800000e+03,   3.58900000e+03,   3.59000000e+03])

# %%
genome_stats.columns
# Out:
# Index([u'contig', u'locus', u'stacks_CatID', u'stacks_SNP', u'LG', u'cM',
#        u'BSname', u'prob_bayescan', u'log10(PO)_bayescan', u'qval_bayescan',
#        u'alpha_bayescan', u'Fst_bayescan', u'mlog10(qval)_bayescan',
#        u'Fst_weir', u'locnum', u'cpvals', u'zscore', u'reject_null',
#        u'reject_null_LFMM', u'fdr_pval_LFMM', u'cM_pad', u'cM_padded'],
#       dtype='object')

# %%
rolling = roll_along(data = genome_stats, stat = 'Fst_bayescan', positions = cMs)
rolling = pd.merge(rolling, roll_along(data = genome_stats, stat = 'Fst_weir', positions = cMs))
rolling = pd.merge(rolling, roll_along(data = genome_stats, stat = 'mlog10(qval)_bayescan', positions = cMs)  )
rolling = pd.merge(rolling, roll_along(data = genome_stats, stat = 'alpha_bayescan', positions = cMs))
rolling = pd.merge(rolling, roll_along(data = genome_stats, stat = 'zscore', positions = cMs))
rolling = pd.merge(rolling, roll_along(data = genome_stats, stat = 'fdr_pval_LFMM', positions = cMs))

# %% [markdown]
# #### Rolling bootstrap 95% upper bounds

# %%
rolling = pd.merge(rolling, rolling_boostrap(data = genome_stats, stat = 'Fst_bayescan', positions = cMs))
rolling = pd.merge(rolling, rolling_boostrap(data = genome_stats, stat = 'Fst_weir', positions = cMs))
rolling = pd.merge(rolling, rolling_boostrap(data = genome_stats, stat = 'mlog10(qval)_bayescan', positions = cMs)  )
rolling = pd.merge(rolling, rolling_boostrap(data = genome_stats, stat = 'alpha_bayescan', positions = cMs))
rolling = pd.merge(rolling, rolling_boostrap(data = genome_stats, stat = 'zscore', positions = cMs))
rolling = pd.merge(rolling, rolling_boostrap(data = genome_stats, stat = 'fdr_pval_LFMM', positions = cMs))

# %%
rolling.head()
# Out:
#    pos   n  Fst_bayescan_roll  Fst_weir_roll  mlog10(qval)_bayescan_roll  \
# 0    1  56           0.033403       0.039550                         inf
# 1    2  57           0.034389       0.042102                         inf
# 2    3  25           0.037950       0.055490                    0.325313
# 3    4  22           0.033544       0.041900                    0.197809
# 4    5  26           0.032396       0.038315                    0.153070
#
#    alpha_bayescan_roll  zscore_roll  fdr_pval_LFMM_roll  \
# 0             0.078582    -0.358948            0.861930
# 1             0.099764    -0.459661            0.832397
# 2             0.175033    -0.203751            0.862572
# 3             0.090312     0.068506            0.914293
# 4             0.068075     0.308946            0.927653
#
#    Fst_bayescan_bootstrap95  Fst_weir_bootstrap95  \
# 0                  0.032900              0.036264
# 1                  0.033405              0.037376
# 2                  0.035960              0.042296
# 3                  0.034910              0.041137
# 4                  0.035406              0.041132
#
#    mlog10(qval)_bayescan_bootstrap95  alpha_bayescan_bootstrap95  \
# 0                                inf                    0.062908
# 1                                inf                    0.080860
# 2                           0.309599                    0.105206
# 3                           0.262756                    0.093867
# 4                           0.309654                    0.106079
#
#    zscore_bootstrap95  fdr_pval_LFMM_bootstrap95
# 0            0.038756                   0.954549
# 1            0.106058                   0.959125
# 2            0.273587                   0.972624
# 3            0.203829                   0.970270
# 4            0.236709                   0.973077

# %% [markdown]
# # Manhattan plot
# could color individual outliers

# %%
import matplotlib.patches

# Manhattan plot
stat = 'Fst_bayescan'
g = sns.lmplot(data = genome_stats, x = 'cM_padded', y = stat,  fit_reg=False, sharex=False,
           legend= False, size = 8, aspect = 8, truncate = True, scatter_kws={'s':50, 'alpha':.7}, palette="Set2", 
              #hue = 'paper1_LG',
              )
g.set(xlim=-40, ylim = -.05)
g.set(xticks=cumpos['cM_pad']+30, xticklabels = np.arange(1, 38))
g.set_axis_labels('LG')
sns.despine(left=True, bottom = True)

# add rolling mean of stat
plt.plot(cMs, rolling[stat+'_roll'], color = 'black')

        
# significant differnatiation regions identified by bootstrap
for idx, vals in rolling.iterrows():
    if vals['Fst_weir_roll'] >= vals['Fst_weir_bootstrap95']:
        currentAxis = plt.gca()
        currentAxis.add_patch(matplotlib.patches.Rectangle((vals['pos'], 0),  1, .008, alpha = 1, color = 'red', label = 'Weir_Fst'))

for idx, vals in rolling.iterrows():
    if vals['mlog10(qval)_bayescan_roll'] >= vals['mlog10(qval)_bayescan_bootstrap95']:
        currentAxis = plt.gca()
        currentAxis.add_patch(matplotlib.patches.Rectangle((vals['pos'], -0.01),  1, .008, alpha = 1, color = 'blue', label = 'Bayescan'))
        
for idx, vals in rolling.iterrows():
    if vals['Fst_bayescan_roll'] >= vals['Fst_bayescan_bootstrap95']:
        currentAxis = plt.gca()
        currentAxis.add_patch(matplotlib.patches.Rectangle((vals['pos'], -0.02),  1, .008, alpha = 1, color = 'green', label = 'Bayescan_Fst'))       

for idx, vals in rolling.iterrows():
    if vals['zscore_roll'] >= vals['zscore_bootstrap95']:
        currentAxis = plt.gca()
        currentAxis.add_patch(matplotlib.patches.Rectangle((vals['pos'], -0.03),  1, .008, alpha = 1, color = 'purple', label = 'zscore'))        


#plt.savefig(os.path.join('paper', 'figures', 'Bayescan_Fst_and_bootstrap.png'))
plt.savefig(os.path.join('paper', 'figures', 'LFMM_quantsem.png'))
plt.show()
        
        
        
        
        
#plt.savefig(os.path.join('paper', 'figures', 'LFMM_quantsem.png'))
plt.show()

# %%
1/(np.exp(2.5/1))
# Out:
# 0.0820849986238988

# %%
import matplotlib.patches

# Manhattan plot
stat = 'zscore'
g = sns.lmplot(data = genome_stats, x = 'cM_padded', y = stat,  fit_reg=False, sharex=False,
           legend= False, size = 8, aspect = 8, truncate = True, scatter_kws={'s':50, 'alpha':.7}, palette="Set2", 
              #hue = 'paper1_LG',
              )
g.set(xlim=-40)
g.set(xticks=cumpos['cM_pad']+30, xticklabels = np.arange(1, 38))
g.set_axis_labels('LG')
sns.despine(left=True, bottom = True)

# add rolling mean of stat
plt.plot(cMs, rolling[stat+'_roll'], color = 'black')



#plt.savefig(os.path.join('paper', 'figures', 'Bayescan_Fst_and_bootstrap.png'))
#plt.savefig(os.path.join('paper', 'figures', 'LFMM_quantsem.png'))
plt.show()
        
        
        
        
        
#plt.savefig(os.path.join('paper', 'figures', 'LFMM_quantsem.png'))
plt.show()

# %%
assert False

# %% [markdown]
# ## Plot of LEPMAP map

# %%
figsize(16, 6)

plt.scatter(x = mapped_loci.paper1_LG, y = mapped_loci['cM'], alpha = .5, s = 30, c = 'blue')
plt.xlim(0, 38); 
plt.ylim(-5); 
plt.xlabel('LG',fontsize = 24); plt.ylabel("cM",fontsize = 24)
plt.xticks(range(1, max(mapped_loci.LEP_LG)+1), fontsize = 16)
plt.show()

# %% [markdown]
# ## WORKING HERE

# %%
pop_loci = pd.read_csv('/home/ipseg/Desktop/waples/chum_populations/data/batch_4/pop_genotypes/on_map.map', 
            sep = '\t', header = None)
pop_loci.columns = ['LEP_LG', 'stacks_SNP', 'junk', 'pos']
pop_loci = pop_loci[['stacks_SNP']]
print(len(pop_loci))
pop_loci.head()
# Out:
# 7259
#   stacks_SNP
# 0     8315_6
# 1    36304_6
# 2    41478_6
# 3     6516_7
# 4    41929_7

# %%
all_mapped_snps = pd.merge(pop_loci, mapped_loci, on = 'stacks_SNP')

# %% [markdown]
# #### notice this is a *.map file produced by the 'populations' program from Stacks, not LEPmap

# %%
non_paralogs_snpfile = "/home/ipseg/Desktop/waples/chum_populations/results/batch_4/pop_analysis/non_paralogs.map"
non_paralog_loci = pd.read_csv(non_paralogs_snpfile, sep ="\t", header = None, comment = "#")
non_paralog_loci.columns = ['contig', 'stacks_SNP', 'ignore', 'pos']
non_paralog_loci = non_paralog_loci[['stacks_SNP']]
non_paralog_loci.head()
# Out:
#   stacks_SNP
# 0     1013_6
# 1     2062_6
# 2     2574_6
# 3     2741_6
# 4     4096_6

# %%
mapped_non_paralogs = pd.merge(non_paralog_loci, mapped_loci, on = 'stacks_SNP')
mapped_non_paralogs.head(5)
# Out:
#   stacks_SNP  contig resolved_locus  stacks_CatID  LEPname  LEP_LG  cM_OLD  \
# 0    24882_6   c3902         3902_C         24882     3907       6  101.52
# 1      561_7  c10621          10621           561      140       5  128.57
# 2    54726_8  c74730        74730_C         54726    10778       9   11.38
# 3    54726_8  c74730        74730_E         54726    10779      33   16.67
# 4    66820_8   c9054           9054         66820    11873      36   51.31
#
#    paper1_LG      cM
# 0         34  101.52
# 1          2    8.89
# 2         29  102.52
# 3         27   20.11
# 4         36   51.31

# %% [markdown]
# ### plot mapped SNPs that we observe in the population data

# %%
plt.scatter(x = mapped_non_paralogs.paper1_LG, y = mapped_non_paralogs.cM, alpha = .3, s = 30, c = 'blue')
plt.xlim(0, 38); 
plt.ylim(-5); 
plt.xlabel('LG',fontsize = 24); plt.ylabel("cM",fontsize = 24)
plt.xticks(range(1, max(mapped_non_paralogs.paper1_LG)+1), fontsize = 16)
plt.show()

# %% [markdown]
# ### First look at Fst across the genome

# %%
pop_fst = pd.read_csv('/home/ipseg/Desktop/waples/chum_populations/data/batch_4/pop_genotypes/non_paralogs.fst', sep= '\t')
pop_fst.rename(columns = {'SNP':'stacks_SNP'}, inplace=True)
pop_fst.head()
# Out:
#    CHR stacks_SNP  POS  NMISS       FST
# 0    0     1013_6    6    168  0.015589
# 1    0     2062_6    6    171 -0.002161
# 2    0     2574_6    6    169  0.017541
# 3    0     2741_6    6    166 -0.005708
# 4    0     4096_6    6    169  0.010227

# %%
map_pop_fst = pd.merge(mapped_non_paralogs, pop_fst, on = 'stacks_SNP')

# %%
bayescan_results = pd.read_csv('/home/ipseg/Desktop/waples/chum_populations/results/batch_4/pop_analysis/mapped_bayescan.txt', sep = "\t")
bayescan_results.head()
# Out:
#   stacks_SNP  BSname       fst  log10(PO)     qval
# 0     1013_6       1  0.027249   -1.05241  0.85034
# 1     2062_6       2  0.026264   -0.88871  0.67027
# 2     2574_6       3  0.027457   -1.15920  0.88696
# 3     2741_6       4  0.026212   -0.90172  0.69108
# 4     4096_6       5  0.027189   -1.02750  0.83277

# %%
map_fst = pd.merge(map_pop_fst, bayescan_results, on = 'stacks_SNP')
map_fst.shape
# Out:
# (6251, 17)

# %%
map_fst.rename(columns = {'FST':'WC_Fst', 'fst':'BS_Fst'}, inplace = True)
map_fst.to_csv('/home/ipseg/Desktop/waples/chum_populations/results/batch_4/pop_analysis/map_fst.txt', sep = "\t", index = False)
map_fst.head()
# Out:
#   stacks_SNP  contig resolved_locus  stacks_CatID  LEPname  LEP_LG  cM_OLD  \
# 0      561_7  c10621          10621           561      140       5  128.57
# 1    66820_8   c9054           9054         66820    11873      36   51.31
# 2    39412_9  c56204          56204         39412     7242       5  127.73
# 3   31566_11  c46960          46960         31566     5348      13    6.66
# 4   38281_11  c54870          54870         38281     6932      13    4.69
#
#    paper1_LG     cM  CHR  POS  NMISS    WC_Fst  BSname    BS_Fst  log10(PO)  \
# 0          2   8.89    2    7    167 -0.003770      65  0.026871   -1.01000
# 1         36  51.31   36    8    168 -0.001607     186  0.026625   -0.95997
# 2          2   9.73    2    9    158  0.028033     221  0.027779   -1.11930
# 3         35   6.66   35   11    158 -0.020896     348  0.026515   -0.95899
# 4         35   4.69   35   11    165  0.019863     353  0.027615   -1.13960
#
#       qval
# 0  0.81994
# 1  0.77155
# 2  0.88069
# 3  0.77000
# 4  0.88462

# %%
sns.set(font_scale=2)
figsize(16, 120)

fig, axarr = plt.subplots(nrows = 37, sharey=True, sharex=True)
for idx, LG in enumerate(set(map_pop_fst.paper1_LG)):
    LG_data = map_pop_fst[map_pop_fst.paper1_LG == LG]
    axarr[idx].scatter(x=LG_data.cM, y=LG_data.FST , alpha = .2, s = 60)
    axarr[idx].axhline(c= 'grey',ls = '--')
    axarr[idx].set_title(LG)

plt.xlim(-1, max(map_pop_fst.cM)+1)
plt.tight_layout()
plt.show()

# %%
### similar in seaborn

# %%
# %matplotlib inline
# lowess fits are too broad
g = sns.FacetGrid(map_pop_fst, row="LEP_LG", size=5, aspect = 3)
g.map(sns.regplot, 'cM', 'FST', ci = 95, scatter = True, lowess = True, truncate= True)
g.set(xlim=(0, max(map_pop_fst.cM)))

# %%
# %matplotlib inline
import statsmodels.api as sm
figsize(16, 120)
# some code adapted from:
#http://nbviewer.ipython.org/urls/gist.githubusercontent.com/TomAugspurger/6e052140eaa5fdb6e8c0/raw/811585624e843f3f80b9b6fe89e18119d7d2d73c/dplyr_pandas.ipynb

fig, axarr = plt.subplots(nrows = 37, sharey=True, sharex=True)
for idx, LG in enumerate(set(map_pop_fst.LEP_LG)):
    LG_data = map_pop_fst[map_pop_fst.LEP_LG == LG]
    smooth = sm.nonparametric.lowess( LG_data.FST, LG_data.cM, frac=.1)
    axarr[idx].plot(smooth[:, 0], smooth[:, 1], linewidth=3);
    std = smooth[:, 1].std()
    axarr[idx].fill_between(smooth[:, 0], smooth[:, 1] - std, smooth[:, 1] + std, alpha=.25);
    axarr[idx].scatter(x=LG_data.cM, y=LG_data.FST , alpha = .5, s = 60)
    axarr[idx].axhline(c= 'grey',ls = '--')
    axarr[idx].set_title(LG)

plt.xlim(-1, max(map_pop_fst.cM)+1)
plt.tight_layout()
plt.show()

# %%
sm.nonparametric.lowess(map_pop_fst.FST, map_pop_fst.cM, =1)
# Out:
# array([[  0.00000000e+00,   2.17126403e-02],
#        [  0.00000000e+00,   2.17126403e-02],
#        [  0.00000000e+00,   2.17126403e-02],
#        ...,
#        [  1.45030000e+02,   2.27927507e-02],
#        [  1.45030000e+02,   2.27927507e-02],
#        [  1.53200000e+02,   2.29106823e-02]])

# %% [markdown]
# ## Look at overlap

# %%
LEPmap_v_pop = pd.merge(pop_snps, mapnames, on = 'match', how = 'inner')
LEPmap_v_pop.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-da64b9bc3bd7> in <module>()
# ----> 1 LEPmap_v_pop = pd.merge(pop_snps, mapnames, on = 'match', how = 'inner')
#       2 LEPmap_v_pop.head()
#
# NameError: name 'mapnames' is not defined

# %%
LEPmap_v_pop_to_print = LEPmap_v_pop[['stacks_SNP', 'contig', 'LEP_LG']]

LEPmap_v_pop_to_print.to_csv('/home/ipseg/Desktop/waples/chum_populations/data/batch_4/lep_v_pop.txt', 
                                             sep = "\t", index = False)

# %%
## Retained in populations after filtering

# %%
retained_pop_snpfile = "/home/ipseg/Desktop/waples/chum_populations/data/batch_4/pop_genotypes/final.snplist"
retained_pop_snps = pd.read_csv(retained_pop_snpfile, sep = "\t", header = None)
retained_pop_snps.columns = ['stacks_SNP']
retained_pop_snps.head()
# Out:
#   stacks_SNP
# 0     1013_6
# 1     2062_6
# 2     2574_6
# 3     2741_6
# 4     4096_6

# %%
retained = pd.merge(LEPmap_v_pop, retained_pop_snps)
print(retained.shape)
retained.head()
# Out:
# (1926, 8)
#    contig stacks_SNP  ignore  pos  match  lepname  mapname  LG
# 0  c10001       2_70       0   70  10001        1    10001  10
# 1  c10068      63_53       0   53  10068       15  10068_A  37
# 2  c10068      63_53       0   53  10068       16  10068_B   9
# 3  c10081      76_65       0   65  10081       18    10081   1
# 4  c10098      90_75       0   75  10098       24    10098  17

# %%
chum_08_map_filename = '/olympus/WORK/WAPLES/Stacks_mapping/Chum_data/consensus/chum_08_PSV_map_ALIGNED.tsv'
chum_08_map = pd.read_csv(chum_08_map_filename, sep = "\t", header = None)
chum_08_map.columns = ['LG', 'SNPx', 'cM']
chum_08_map['match'] = [xx[0] for xx in chum_08_map['SNPx'].str.split("_") ]

pd.merge(pop_snps, chum_08_map).head()
# Out:
#    contig stacks_SNP  ignore  pos  match  LG      SNPx       cM
# 0  c10001       2_70       0   70  10001  29  10001_x1    4.986
# 1  c10068      63_53       0   53  10068  28  10068_x2  111.654
# 2  c10068      63_53       0   53  10068  15  10068_x1   55.225
# 3  c10081      76_65       0   65  10081   0  10081_x1   67.785
# 4  c10106     100_35       0   35  10106   0  10106_x1   77.872

# %%
aa = pd.merge(mapnames, chum_08_map, on =['match'])
aa = aa[aa['match'] != 'Oke']
bb = pd.merge(aa, pop_snps)
bb = bb.drop_duplicates(['lepname'])
bb.head()
bb.shape
# Out:
# (1429, 11)

# %%
# !pwd
# Out:
# /home/ipseg/Desktop/waples/chum_populations
